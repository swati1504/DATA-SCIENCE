# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,3,4]
y=[4,15,9]
plt.plot(x,y,color="red")
plt.show()

# %%
x=[1,3,4]
y=[4,15,9]
plt.plot(x,y,color="green",marker="*",markersize=15,linestyle="dashed",linewidth=3)
plt.show()

# %%
plt.plot(x,y,"r--o")

plt.title("Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
plt.bar(x,y,color="blue")

plt.title("Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
x1=[1,2,3]
y1=[3,9,4]

x2=[1,2,3]
y2=[5,2,7]

plt.plot(x1,y1,label="blue")
plt.plot(x2,y2,label="orange")

plt.legend()
plt.title("Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %% [raw]
# use plt.legend() for the labels on the graphs

# %%
plt.figure(figsize=[10,10])
x1=[1,2,3]
y1=[3,9,4]

x2=[1,2,3]
y2=[5,2,7]

plt.plot(x1,y1,label="blue")
plt.plot(x2,y2,label="orange")

plt.legend()
plt.title("Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
x1=[1,2,3]
y1=[3,9,5]

x2=[1,2,3]
y2=[5,2,4]

plt.bar(x1,y1,label="blue")
plt.bar(x2,y2,label="orange")

plt.legend()
plt.title("Graph")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %% [raw]
# //orange overlaps blue on the above figure

# %%
x=[1,3,2,5,6,2]
y=[2,6,9,4,1,3]

# %%
plt.scatter(x,y,s=50)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.barh(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
company=["Google","Microsoft","Adobe","Facebook"]
revenue=[20,40,50,60]
profit=[10,24,36,29]

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue,label="Revenue")
plt.bar(xpos,profit,label="Profit")
plt.xticks(xpos,company)
plt.legend()
plt.title("Stocks")
plt.show()

# %%
plt.bar(xpos-.2,revenue,label="Revenue",width=.4)
plt.bar(xpos+.2,profit,label="Profit",width=.4)
plt.xticks(xpos,company)
plt.legend()
plt.title("Stocks")
plt.show()

# %%
exp_vals=[100,150,300,400]
exp_labels=["A","B","C","D"]

# %%
plt.pie(exp_vals,labels=exp_labels)
plt.show()

# %%
plt.pie(exp_vals,labels=exp_labels,radius=2.0)
plt.show()

# %%
plt.pie(exp_vals,labels=exp_labels,autopct="%1.2f%%")
plt.show()

# %%
plt.pie(exp_vals,labels=exp_labels,autopct="%1.1f%%",explode=(0,0,0.1,0))
plt.show()

# %%
plt.bar(exp_labels,exp_vals,color="green",width=0.5)
plt.show()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [raw]
# //data about a restaurant

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %% [raw]
# //frequency of univariate data-histogram
# //to compare values-bar plot
# //to find out a trend of the data-scatter plot

# %%
sns.barplot(tips["total_bill"],tips["tip"])
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tips["total_bill"],tips["tip"])
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,color="red")
plt.show()

# %%
sns.displot(tips["total_bill"],color="green")
plt.show()

# %%
sns.displot(tips["total_bill"],color="purple",kind="kde")
plt.show()

# %%
sns.distplot(tips["total_bill"],color="purple")
plt.show()
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(tips["total_bill"],color="purple",kde=True,bins=10)
plt.show()

# %%
sns.boxplot(x="tip",data=tips)
plt.show()

# %%
sns.boxplot(x="day",y="tip",data=tips)
plt.show()

# %% [raw]
# //INFERENCES FROM THE GRAPH
# Friday..ppl are not paying much
# Median almost same for all days
# Sunday more payment(very high IQR)
# Several outliners in Sat
# Thursday min tip is higher than the other days

# %%
sns.boxplot(x="day",y="total_bill",data=tips)
plt.show()

# %% [raw]
# //INFERENCES FROM THE GRAPH
# median 12 to 20 range
# more outliners on thursday
# Sunday more payment(median is highest)
# Min total bill is max on Sun
# Sat..since min bill is min on sat..that is ppl mark their presence
# Ppl eat more on weekends

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x="day",y="total_bill",hue="smoker",data=tips)
plt.show()

# %% [raw]
# //INFERENECES
# Ppl not smoking much on fri
# Sat Sun more smoke
# smokers are having more total bills compared to non smokers
# outliners more on sat

# %%
plt.figure(figsize=(8,4))
sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.swarmplot(x="day",y="total_bill",hue="sex",data=tips)
plt.show()

# %% [markdown]
# # DATA OF TV,RADIO,NEWSPAPER ADVERTISING UNITS AND ITS CORRESPONDING SALES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Advertising.csv",index_col=0)
df
# Out:
#         TV  Radio  Newspaper  Sales
# X1
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [raw]
# //continuous data-linear regression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
df.TV
# Out:
# X1
# 1      230.1
# 2       44.5
# 3       17.2
# 4      151.5
# 5      180.8
#        ...
# 196     38.2
# 197     94.2
# 198    177.0
# 199    283.6
# 200    232.1
# Name: TV, Length: 200, dtype: float64

# %%
sns.boxplot(x="TV",data=df)
plt.show()

# %%
sns.boxplot(x="Newspaper",data=df)
plt.show()

# %% [raw]
# //A lot of money is spent on newspapers(see outliners also)

# %%
plt.figure(figsize=[10,10])
x1="TV"
y1="Sales"

x2="Radio"
y2="Sales"

plt.scatter(x1,y1,data=df,label="TV")
plt.scatter(x2,y2,data=df,label="Radio")

plt.legend()
plt.title("Graph")
plt.xlabel("Adv Units")
plt.ylabel("Sales")
plt.show()

# %%
# %matplotlib inline

# %%
sns.pairplot(df, x_vars=["","TV","Radio","Newspaper"], y_vars= "Sales")
plt.show()

# %% [raw]
# //TV has a good correlation...u would be much confident while predicting the values

# %%
sns.pairplot(df, x_vars=["","TV","Radio","Newspaper"], y_vars= "Sales",height=10)
plt.show()

# %% [raw]
#  //graph incorrect coz x scaling is incorrect...all the graphs don't have the same x scaling

# %%
sns.pairplot(df, x_vars=["","TV"], y_vars= "Sales",height=4)
plt.show()

# %%
sns.pairplot(df, x_vars=["","Radio"], y_vars= "Sales",height=6)
plt.show()

# %% [raw]
# //Inference from the above 2 graphs
# At 50,000 adv units, sales of TV is around 10,000...but
# since the correlation is so good u r confident abt the analysis
# sales of Radio at 50,000 adv units has a very big range
# from 7 to 30 but most of the time greater than 10,000 but u are
# less confident coz of the weak correlation....
# We can say that Radio gives us more sales than TV

# %%
sns.pairplot(df, x_vars=["","Newspaper"], y_vars= "Sales",height=6)
plt.show()

# %%
corr_df=df.corr()
corr_df
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(corr_df,annot=True)
plt.show()

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [raw]
# //inference
# TV: 50% of the time adv units spent=(218-74=144)
# Radio:50% of the time adv units spent=(36-10=26)
# Newspaper:50% of the time adv units spent=(45-12=33)
# So we can say that we spend the least on radio advtng

# %% [raw]
# //LINEAR REGRESSION
# Sales-DV
# TV,RAD,NP-InV

# %%
feature_cols=["TV"]

x=df[feature_cols]
x
# Out:
#         TV
# X1
# 1    230.1
# 2     44.5
# 3     17.2
# 4    151.5
# 5    180.8
# ..     ...
# 196   38.2
# 197   94.2
# 198  177.0
# 199  283.6
# 200  232.1
#
# [200 rows x 1 columns]

# %%
y=df["Sales"]
y
# Out:
# X1
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# # Splitting the data in Training and Testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=123)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (150, 1)
# (50, 1)
# (150,)
# (50,)

# %% [raw]
# //random 75%-train data
# other 25%-test data

# %%
from sklearn.linear_model import LinearRegression

# %%
#initiate
linreg=LinearRegression()

# %%
#apply LR
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linreg.intercept_
# Out:
# 7.0321256400610315

# %%
linreg.coef_
# Out:
# array([0.04726633])

# %%
sales1=7.03 + (.047 * 147.3)
sales1
# Out:
# 13.953100000000001

# %%
actual_val=14.6

# %%
error=actual_val - sales1
error
# Out:
# 0.6468999999999987

# %% [raw]
# //some errors are +ve and some -ve ...they can
# nullify which will not find the right error and the corresponding graph...therefore we use root mean squared error

# %%
y_pred=linreg.predict(x_test)
y_pred
# Out:
# array([16.4759376 , 10.822885  , 10.5629202 ,  9.14493042, 13.99445548,
#        18.29096452, 14.85942925, 15.66295679, 15.93710148,  7.58514166,
#        10.59128   , 16.7217225 ,  9.68849317,  7.91600594,  7.65131451,
#        12.36849386, 15.5778774 , 20.11071808,  7.92073257, 17.35509127,
#         7.95854563, 11.20574224,  7.87819288,  9.39544195, 17.44489729,
#         8.29886318, 14.43403231, 13.78648364, 11.57914621, 17.26055861,
#        12.51501947, 18.89124687, 20.62592103,  7.94909237, 16.16397985,
#        17.42126412, 19.02831921, 15.77166934, 14.7507167 , 10.50147398,
#         9.97681776, 20.29978338, 10.72835234, 19.58606186, 17.8230279 ,
#        14.80743629, 15.39826536, 17.54415657, 16.37195168, 12.22196825])

# %%
y_test
# Out:
# X1
# 51     11.4
# 128     8.8
# 38     14.7
# 150    10.1
# 20     14.6
# 105    20.7
# 180    12.6
# 54     21.2
# 163    14.9
# 159     7.3
# 83     11.3
# 186    22.6
# 183     8.7
# 190     6.7
# 109     5.3
# 32     11.9
# 5      12.9
# 179    11.8
# 122     7.0
# 21     18.0
# 173     7.6
# 89     12.9
# 167     8.0
# 171     8.4
# 129    24.7
# 73      8.8
# 181    10.5
# 27     15.0
# 145    11.4
# 53     22.6
# 80     11.0
# 94     22.2
# 184    26.2
# 120     6.6
# 86     15.2
# 134    19.6
# 185    17.6
# 140    20.7
# 96     16.9
# 141    10.9
# 25      9.7
# 151    16.1
# 115    14.6
# 34     17.4
# 24     15.5
# 172    14.5
# 42     17.1
# 101    11.7
# 153    16.6
# 72     12.4
# Name: Sales, dtype: float64

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 2.2998620516177914

# %%
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 9.542934924756379

# %%
#root mean squared error
RMSE_MLR=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
RMSE_MLR
# Out:
# 3.0891641142477972

# %% [markdown]
# # Verdict for Simple Linear Regression
#
# My model will make an error of 3.09 unit while predicting the values of sales considering only TV as InV

# %%
 feature_col=["TV","Radio","Newspaper"]
 x=df[feature_col]
x
# Out:
#         TV  Radio  Newspaper
# X1
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df["Sales"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=123)

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 2.8432421471887928
# [4.63372613e-02 1.85342809e-01 3.56953720e-05]

# %% [raw]
# B0 =2.84(min sales)
# B1 =0.046....1000-->46 units
# B2 =0.185....1000-->185 units
# B3=0.000035..1000-->0.035 units
#
# The above data says that radio gives us the max sales and then TV
# and newspaper compared to them nothing.
# Stop wasting money on advertising newsppr...no sales

# %% [markdown]
# # Statistical way of executing Regression

# %%
import statsmodels.api as sm

# %%
#x=df[["TV","Radio","Newspaper"]]
x=df[["TV"]]
x
# Out:
#         TV
# X1
# 1    230.1
# 2     44.5
# 3     17.2
# 4    151.5
# 5    180.8
# ..     ...
# 196   38.2
# 197   94.2
# 198  177.0
# 199  283.6
# 200  232.1
#
# [200 rows x 1 columns]

# %%
y=df["Sales"]
y
# Out:
# X1
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
linear_model=sm.OLS(y,x).fit()

# %%
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Sales   R-squared (uncentered):                   0.897
# Model:                            OLS   Adj. R-squared (uncentered):              0.896
# Method:                 Least Squares   F-statistic:                              1733.
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):                   3.52e-100
# Time:                        18:37:51   Log-Likelihood:                         -597.51
# No. Observations:                 200   AIC:                                      1197.
# Df Residuals:                     199   BIC:                                      1200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0832      0.002     41.633      0.000       0.079       0.087
# ==============================================================================
# Omnibus:                       20.228   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.930
# Skew:                          -0.846   Prob(JB):                     6.36e-06
# Kurtosis:                       3.086   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [raw]
# //OLS method says square and calculate the method

# %% [raw]
# R-squared: shows the value of the strength of the relationship
# i.e. here 89.7% of the sales can be defined by just the TV
# being the ind var.
# 89.7% sales is because of the TV
# For TV,coeff(B1) =0.0832
# err=0.002....so coeff varies from .081 to .085
# The coeff is different here from .046(initially) coz here sampling has not been done....full 100% data has been taken instead og=f train and test

# %%
x=df[["TV","Radio","Newspaper"]]
x
# Out:
#         TV  Radio  Newspaper
# X1
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df["Sales"]
y
# Out:
# X1
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
linear_model=sm.OLS(y,x).fit()

# %%
linear_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Sales   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              3566.
# Date:                Fri, 15 Oct 2021   Prob (F-statistic):                   2.43e-171
# Time:                        18:48:55   Log-Likelihood:                         -423.54
# No. Observations:                 200   AIC:                                      853.1
# Df Residuals:                     197   BIC:                                      863.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# TV             0.0538      0.001     40.507      0.000       0.051       0.056
# Radio          0.2222      0.009     23.595      0.000       0.204       0.241
# Newspaper      0.0168      0.007      2.517      0.013       0.004       0.030
# ==============================================================================
# Omnibus:                        5.982   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                7.039
# Skew:                          -0.232   Prob(JB):                       0.0296
# Kurtosis:                       3.794   Cond. No.                         12.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
